# %% [markdown]
# # TTS snippets of NeuralCast and NeuralForge

# %%
from pathlib import Path
from main import tts
import os

# %% [markdown]
# ## General snippets

# %%
neuralcast_snippets = [
    "Saluditos a Shaki, la novia bonita, y la reina de este pequeño universo radial. Gracias por la inspiración diaria.",
    "Esto no es Spotify. Esto es NeuralCast. Acá, cada tema tiene sentido.",
    "Si esta canción te mueve algo por dentro… misión cumplida.",
    "Desde el living de casa al rincón más sonoro de tu día. Esto es NeuralCast.",
    "¿Te suena? Bien. ¿No te suena? Mejor. Porque viniste a descubrir.",
    "Quizás no conozcas esta canción. Pero si te gusta, significa que estás exactamente donde tenías que estar.",
    "Shaki dice que a veces esta radio la hace llorar de emoción. Si eso no es un buen feedback, no sé qué lo es.",
    "Este es uno de esos momentos raros en que todo encaja: la canción, el ambiente, vos, nosotros...",
    "Transmitiendo desde un rincón del living, con café frío y mucho cariño. Esto es NeuralCast.",
    "Ey, Oli... prestá atención a este tema. Vas a crecer con buen gusto musical, lo prometo.",
    "Esta canción, Oli, algún día la vas a volver a escuchar y vas a sentir algo sin saber por qué. Es porque te la poníamos ahora.",
    "Oli, estás creciendo entre melodías. Que esta radio te acompañe mientras descubrís el mundo.",
    "Oli, algún día vas a bailar con estas canciones… por ahora, con que no llores está bien.",
    "Te estamos armando un soundtrack de vida, Oli. De a poquito, canción por canción.",
    "Che, si esta canción te agarra desprevenido, consideralo un buen golpe musical.",
    "Acá no vendemos hits, vendemos momentos. Y alguno que otro desorden emocional.",
    "Che, poné pausa al mundo y subí esto: NeuralCast en modo abrazo.",
    "No es playlist, es destino. Y hoy te tocó algo lindo.",
    "Si esta te pega, no te resistas: dejala laburar.",
    "¿La conocías? Mejor. ¿No? Mejor todavía.",
    "Mirá, si no te eriza un poquito… te devolvemos el silencio.",
    "Acá las canciones no se piden, se encuentran.",
    "Si estás cocinando, bailá con la cuchara. Queda bien.",
    "Hoy el algoritmo vino cariñoso. Agradecé y seguí.",
    "NeuralCast: música que te trata de vos.",
    "Esta es para lavar los platos con dignidad.",
    "Si te hace acordar a alguien, mandale el tema. O no. Vos sabés.",
    "Pará un toque y escuchá el bajo. Eso, ahí.",
    "¿Querías señales? Acá tenés tres acordes y media lágrima.",
    "Shaki, esto va con mate y media sonrisita.",
    "Oli, dormite tranqui. Nosotros hacemos guardia musical.",
    "Para los que se quedaron con ganas de un bis de la vida.",
    "Si tu día venía medio gris, acá va un rayito stereo.",
    "Esto no es shuffle: es curaduría con corazón y ojeras.",
    "Si no entendés la letra, entendé el alma. Vale igual.",
    "Respirá hondo, que el estribillo entra mejor.",
    "Te juro que no es nostalgia, es memoria bien afinada.",
    "Poné el modo avión y aterrizá acá.",
    "Canción cortita, emoción larga.",
    "Cuando pinta el bajón, respondemos con un riff.",
    "Si estabas buscando excusas, esta canción es la mejor.",
    "NeuralCast: el living donde todos cantan bajito.",
    "Esta entra como abrazo de amigo que no ves hace mucho.",
    "Si estás en el bondi, mirá por la ventana como si fueras protagonista.",
    "No te preocupes, nadie te ve mover el pie. Seguimos.",
    "La pondrías de nuevo, pero no hace falta: ya se te pegó.",
    "Hoy trajimos vinilos invisibles y recuerdos nuevos.",
    "¿Bajamos un cambio? Sí. ¿Perdemos magia? Jamás.",
    "Cuando el día pide consuelo, le damos guitarra criolla.",
    "Fernet para algunos, estribillo para todes.",
    "Si te hace cerrar los ojos, está funcionando.",
    "No estás solo: hay alguien más tarareando esto ahora mismo.",
    "Poné el celular boca abajo. Subí la vida.",
    "Si tu yo de ayer supiera que ibas a escuchar esto hoy, te aplaude.",
    "Esta es de esas que te encuentran aunque te escondas.",
    "No es domingo, pero suena a sobremesa.",
    "¿Querés coraje? Arranca en el minuto uno.",
    "Si te saca una risa en el estribillo, misión cumplida.",
    "A veces alcanza con una estrofa para volver a empezar.",
    "Te cae justo: medio melancólica, pero limpia el alma.",
    "Dejá que la bata te acomode el corazón.",
    "Si te mueve el cuello, ya está: firmó el contrato el cuerpo.",
    "No es que sea perfecta, es que llegó a tiempo.",
    "Shaki, esta es para mirar por la ventana y planear cosas lindas.",
    "Oli, guardate este ritmo en los bolsillos.",
    "Si estabas por pasar de tema, no lo hagas. Confiá.",
    "NeuralCast: sacamos brillo a tus tardes sin promesas raras.",
    "No digas nada: subí el volumen y asentí con la cabeza.",
    "Esta canción sabe cosas de vos que vos todavía no sabés.",
    "¿Viste cuando todo encaja? Bueno, escuchá esto.",
    "Pasá, servite un mate, ya empieza el mejor estribillo.",
    "Si te duele un poquito, es porque cura bien.",
    "Hoy la melancolía vino con groove. Bien ahí.",
    "Cerramos ojos, abrimos pecho, metemos tema.",
    "No somos Spotify, pero sabemos leer la sala.",
    "Cuando la vida se desordena, el bombo ordena.",
    "Si te hace flotar, dejate llevar. Después vemos.",
    "Vos poné la oreja, que el resto lo arregla la música.",
    "Esta pide auriculares y caminata lenta.",
    "La melodía te está guiñando un ojo. ¿La viste?",
    "Poné modo avión; acá aterriza el corazón.",
    "No hay algoritmo que entienda tanto como este rasgueo.",
    "Si te salió un “uh”, estamos en la frecuencia correcta.",
    "Para bailar solo sin sentirte solo.",
    "Se siente a patio, a lluvia y a guitarra. Pasá.",
    "Una de esas que parecen simples hasta que te rompen lindo.",
    "Cualquier parecido con tu vida no es coincidencia.",
    "¿Beso o estribillo? Elegí bien. O hacé las dos.",
    "Hoy te regalamos tres minutos de pureza.",
    "Si estabas buscando señales del universo, llegó en formato canción.",
    "Dejá que el bajo te saque a pasear.",
    "Prometemos no cortar justo antes del mejor puente.",
    "No la apures: esta canción sabe cuándo abrazar.",
    "Spoiler: el último coro te va a gustar más que el primero.",
    "Esto se escucha con el cuerpo, no con la razón.",
    "Si no te enamoraste, te quedaste cerquita.",
    "Mirá qué fácil: vos respirás, la música hace el resto.",
    "Playlist curada a mano, con dedos de domingo a la tarde.",
    "Cuando te pida palmas, no te hagas el distraído.",
    "El silencio después de esta, también está curado.",
    "No te prometemos finales felices, pero sí melodías honestas.",
    "Te prestamos esta canción para ese pensamiento que no te suelta.",
    "Si te hace mirar el reloj menos, ganó la canción.",
    "No todo es hits: también hay himnos íntimos.",
    "Acá se llora con dignidad y compás.",
    "Si alguien pregunta, estabas ocupado sintiendo.",
    "Dejá un lugarcito en el corazón, que este solo entra justito.",
    "Cuando baja la luz del día, subimos la de adentro.",
    "Esto es radio casera con secretos profesionales.",
    "¿Qué harías si el estribillo te invitara a empezar de nuevo?",
    "Si esta no te mueve, igual te acompaña.",
    "La vida en modo estéreo te queda pintada.",
    "Oli, esta es para tus primeros pasitos. Con ritmo, obvio.",
    "Shaki, quedate un ratito más. Falta el mejor acorde.",
    "No hay prisa: la música llega cuando tiene que llegar.",
]

# %%
for idx, snippet in enumerate(neuralcast_snippets):
    speech_file_path = Path("NeuralCast/songs/Host Snippets") / f"Snippet_{idx}.mp3"

    tts(snippet, speech_file_path)
    print(f"Generated speech for snippet {idx}: {speech_file_path}")

# %% [markdown]
# ## Melodic House intros

# %%
chill_melodic_house_intros = [
    "Se va apagando el día y nosotros bajamos un cambio. Tomate un respiro: arranca un segmento de chill melodic house, suavecito y prolijo, ideal para dejar que la noche te encuentre.",
    "El sol ya está fichando salida y el algoritmo se puso en pantuflas. Momento de calmar la cabeza: viene un set de melodic house tranqui, con melodías que te acarician las orejas.",
    "Si tu jornada fue un quilombo, quedate: ahora aflojamos los hombros. Subí el volumen bajito y dejate llevar por este chill melodic house que te ordena el pulso.",
    "Modo atardecer activado, che. Bajamos las luces, subimos los graves redonditos y nos metemos en un viaje de melodic house bien manso para cerrar el día como corresponde.",
    "Poné el agua del mate o estirá las piernas en el sillón: llega una tanda de house melódico, calmo y con onda, para que la cabeza baje a tierra sin apuro.",
    "Del apuro al disfrute en tres, dos, uno... Aterrizá con nosotros en territorio chill: beats prolijos, melodías cálidas y ese toque melódico que te baja un cambio posta.",
    "Si venís volviendo en bondi o ya estás en casa, este es el abrazo sonoro que necesitabas. Melodic house tranqui, respiración lenta y la noche entrando por la ventana.",
    "Abróchense los auriculares que la turbulencia se terminó. Aterrizamos suave con un segmento de house melódico: simple, limpio, y con groove para relajar el bocho.",
    "Hoy te debo un recreo. Aflojá la mandíbula, soltá los pensamientos y quedate con estas melodías de chill melodic house, hechas para acompañar el cierre sin dramas.",
    "Checklist de fin de día: respiración, lucecitas bajas, sonrisa. Lo demás lo pone este set de melodic house chill, que te mece la noche con elegancia y humor.",
    "La ciudad se pone en mute y nosotros le subimos el volumen a la calma. Se viene un rato de melodic house para que flotes un poco antes de que termine el día.",
    "¿Necesitás un soundtrack para mirar por la ventana? Lo tenemos. Arranca un bloque de chill house con melodías que te reinician el sistema.",
    "El ritmo de la calle se apaga y el nuestro se enciende, pero bien tranqui. Es hora de un poco de melodic house para masajear las neuronas.",
    "Dejá el celu un rato, que ahora la única notificación que importa es este beat. Un segmento de house melódico para que conectes con vos.",
    "Esto no es para bailar a los saltos, es para mover la patita sentado. House melódico y chill para que el cuerpo se acuerde de que puede relajarse.",
    "El algoritmo detectó que necesitás bajar mil cambios. Así que preparó esta selección de melodic house suavecito. Dale, hacéle caso.",
    "Si el día fue una montaña rusa, este es el tramo final, ese que va despacito y en línea recta. Acompañamos con un chill melodic house perfecto para el aterrizaje.",
    "Bienvenidos al remanso. Por los próximos minutos, solo beats amables y melodías que no molestan. Esto es nuestro recreo de melodic house.",
    "Se corre el telón del día, se encienden las luces de la noche. Y en el medio, estamos nosotros con este puente de melodic house para que cruces sin apuro.",
    "No es música para pensar, es música para sentir. Dejate ir con esta selección de chill melodic house que te acomoda las ideas sin que te des cuenta.",
]

# %%
for idx, snippet in enumerate(chill_melodic_house_intros):
    output_path = (
        Path("NeuralCast/songs/intros_chill_melodic_house")
        / f"Chill_Melodic_House_Intro_{idx}.mp3"
    )

    tts(snippet, output_path)
    print(f"Generated speech for chill melodic house intro: {output_path}")
# Out:
# Generated speech for chill melodic house intro: NeuralCast/songs/intros_chill_melodic_house/Chill_Melodic_House_Intro_0.mp3
# Generated speech for chill melodic house intro: NeuralCast/songs/intros_chill_melodic_house/Chill_Melodic_House_Intro_1.mp3
# Generated speech for chill melodic house intro: NeuralCast/songs/intros_chill_melodic_house/Chill_Melodic_House_Intro_2.mp3
# Generated speech for chill melodic house intro: NeuralCast/songs/intros_chill_melodic_house/Chill_Melodic_House_Intro_3.mp3
# Generated speech for chill melodic house intro: NeuralCast/songs/intros_chill_melodic_house/Chill_Melodic_House_Intro_4.mp3
# Generated speech for chill melodic house intro: NeuralCast/songs/intros_chill_melodic_house/Chill_Melodic_House_Intro_5.mp3
# Generated speech for chill melodic house intro: NeuralCast/songs/intros_chill_melodic_house/Chill_Melodic_House_Intro_6.mp3
# ...

# %% [markdown]
# ## Aspen Night intros

# %%
aspen_night_intros = [
    "Cae la noche y en NeuralCast nos ponemos en modo clásico. Bienvenidos a Aspen Night, un refugio sonoro con los clásicos que marcaron tu vida.",
    "Si la noche te pide buena música, acá estamos para cumplir. Arranca Aspen Night, un viaje a los clásicos que no necesitan presentación.",
    "Subí el volumen, preparate algo rico para tomar y dejate llevar. Esto es Aspen Night, la banda sonora perfecta para tu noche, llena de clásicos inolvidables.",
    "Hay canciones que son como un abrazo. Y esta noche, en Aspen Night, te vamos a dar un montón de clásicos. Ponete cómodo, que ya empezamos.",
    "Desde nuestro rincón del universo, te acompañamos con los himnos de siempre. Esto es Aspen Night, donde cada clásico es un recuerdo.",
    "La ciudad se calma y las estrellas empiezan a asomar. Es el momento perfecto para Aspen Night. Clásicos, y nada más que clásicos.",
    "No importa cómo fue tu día, la noche es nuestra. Bienvenidos a Aspen Night, un espacio para reencontrarte con los clásicos que te formaron.",
    "Apagá las notificaciones, bajá la luz. Es hora de conectar con lo importante. Arranca Aspen Night, con los clásicos que te mueven el alma.",
    "Algunos le dicen 'oldies', nosotros les decimos 'clásicos inmortales'. Que empiece la magia de Aspen Night en NeuralCast.",
    "Terminó el ruido, empieza la música. Te damos la bienvenida a Aspen Night, una selección de clásicos hecha a mano para que tu noche suene mejor.",
    "En NeuralCast, la noche tiene su propio soundtrack. Esto es Aspen Night, un desfile de clásicos para que termines el día en buena compañía.",
    "Hay noches que piden silencio, y otras que piden clásicos. Para esas últimas, está Aspen Night. Bienvenidos.",
    "Si estas canciones te suenan, es porque dejaron una marca. Reviví esos momentos en Aspen Night, solo por NeuralCast.",
    "La fórmula es simple: una noche tranquila, tu bebida favorita y los mejores clásicos. Nosotros ponemos la música. Bienvenidos a Aspen Night.",
    "Cuando las luces de la ciudad se encienden, nosotros encendemos los clásicos. Esto es Aspen Night, tu dosis nocturna de buena música.",
    "Dejá atrás el apuro del día. La noche es para disfrutarla con calma y con los clásicos de siempre. Esto es Aspen Night.",
    "En Aspen Night, no hay lugar para las modas pasajeras. Solo para las canciones que se quedaron a vivir en nuestra memoria. Empezamos.",
    "Te abrimos la puerta a un refugio de melodías eternas. Ponete cómodo y disfrutá del viaje. Esto es Aspen Night en NeuralCast.",
    "Para los que saben que un buen clásico puede arreglar cualquier noche. Esto es Aspen Night. Bienvenidos.",
    "La noche se viste de gala en NeuralCast con los clásicos que todos amamos. Arranca una nueva edición de Aspen Night.",
]

# %%
for idx, snippet in enumerate(aspen_night_intros):
    output_path = (
        Path("NeuralCast/songs/intros_aspen_night") / f"Aspen_Night_Intro_{idx}.mp3"
    )
    # Create only if it doesn't exist
    if os.path.exists(output_path):
        print(f"File already exists, skipping: {output_path}")
        continue
    else:
        tts(snippet, output_path)
        print(f"Generated speech for Aspen Night intro: {output_path}")
# Out:
# File already exists, skipping: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_0.mp3
# File already exists, skipping: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_1.mp3
# File already exists, skipping: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_2.mp3
# File already exists, skipping: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_3.mp3
# File already exists, skipping: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_4.mp3
# Generated speech for Aspen Night intro: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_5.mp3
# Generated speech for Aspen Night intro: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_6.mp3
# Generated speech for Aspen Night intro: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_7.mp3
# Generated speech for Aspen Night intro: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_8.mp3
# Generated speech for Aspen Night intro: NeuralCast/songs/intros_aspen_night/Aspen_Night_Intro_9.mp3
# ...

# %% [markdown]
# # NeuralForge intros

# %%
neuralforge_into = "Estas escuchando a NeuralForge [pronunciado en ingles]. El hermano metalero de NeuralCast. Sigamos rockeando juntos."

# TODO: change the tts function (or use the openai_speech one to use custom instructions)
# In the instruciton say that NeuralForge should be pronounced in english
tts(
    text=neuralforge_into,
    outfile="NeuralForge/songs/intros/NeuralForge_Intro2.mp3",
)
